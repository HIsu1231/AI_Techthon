# %% [markdown]
# <a href="https://colab.research.google.com/github/HIsu1231/AI_Techthon/blob/main/Data_PreProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
path = './drive/MyDrive/data/basic_plank/test/1.jpg'

image = cv2.imread('drive/MyDrive/data/basic_plank/test/1.jpg', cv2.IMREAD_GRAYSCALE)

plt.imshow(image, cmap='gray'), plt.axis('off')
plt.show()

# %%
path = './drive/MyDrive/data/basic_plank/test/1.jpg'

image = cv2.imread('drive/MyDrive/data/basic_plank/test/1.jpg', cv2.IMREAD_GRAYSCALE)

max_output_value = 255
neighborhood_size = 99
subtract_from_mean = 10
image_binarized = cv2.adaptiveThreshold(image, max_output_value,
                                        cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,
                                        neighborhood_size, subtract_from_mean)
plt.imshow(image, cmap='gray')
plt.show()

# %%
image_bgr = cv2.imread('drive/MyDrive/3.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (30, 255, 800,357)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg), plt.axis('off')
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()


cv2.imwrite('./drive/MyDrive/1.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/2.jpg',mask_2)
# Out:
# True

# %%
#(30, 255, 800,357)

rgb_cropped = image_rgb_nobg[255:600,30:800]

plt.imshow(rgb_cropped, cmap='gray')
                             
mask_cropped = mask_2[255:600,30:800]
plt.imshow(mask_cropped, cmap='gray')

cv2.imwrite('./drive/MyDrive/1.jpg',rgb_cropped)
cv2.imwrite('./drive/MyDrive/2.jpg',mask_cropped)
# Out:
# True

# %%
image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/2.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (50, 20,480,265)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg), plt.axis('off')
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/2.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/2.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/3.jpg')

image_cropped = image[180:600,220:1000]

image_bgr = image_cropped
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (0, 20,800, 1300)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg), plt.axis('off')
plt.show()

plt.imshow(mask, cmap='gray')
plt.show()

plt.imshow(mask_2, cmap='gray')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/3.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/3.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/4.jfif')
image_cropped = image[300:640,235:930]

image_bgr = image_cropped

#image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/4.jfif')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (0,0,693,370)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/4.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/4.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/elbow_plank/test/5.jpg')
image_cropped = image[100:980,45:1900]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped

#image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/5.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (0,0,1800,2000)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/5.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/5.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/6.png')
image_cropped = image[140:530,180:1000]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped

#image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/6.png')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (10,10,850,500)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/6.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/6.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/7.jpg')
image_cropped = image[200:600,230:990]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped

#image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/7.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (10,10,850,380)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/7.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/7.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/8.jpg')
image_cropped = image[620:1330,350:1900]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped

#image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/7.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (10,10,1600,900)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/8.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/8.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/9.jpg')
image_cropped = image[0:250,0:750]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped

#image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/9.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (0,10,395,188)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/9.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/9.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/11.png')
image_cropped = image[40:260,60:520]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped

#image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/9.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (0,5,420,161)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/11.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/11.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/12.png')
image_cropped = image[100:460,165:920]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped

#image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/9.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (0,10,800,340)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/12.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/12.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/30.jpg')
image_cropped = image[120:280,50:325]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped

#image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/basic_plank/test/29.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (1,1, 320,190)

mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()

cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/basic_plank/test/30.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/basic_plank/test/30.jpg',mask_2)
# Out:
# True

# %%
image = cv2.imread('drive/MyDrive/AI_techthon/original_data/elbow_plank/test/2.webp')
image_cropped = image[130:655,60:1875]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped

#image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/elbow_plank/test/30.jfif')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (50,33,1200,480)
#50, 30, 1218, 480
mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()


cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/test/2.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/test/2.jpg',mask_2)
# Out:
# True

# %%
rgb_cropped = image_rgb_nobg[30:142,20:265]

plt.imshow(rgb_cropped, cmap='gray')
                             
mask_cropped = mask_2[30:142,20:265]
plt.imshow(mask_cropped, cmap='gray')

# %%
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/test/30.jpg',rgb_cropped)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/test/30.jpg',mask_cropped)
# Out:
# True

# %%
'''image = cv2.imread('drive/MyDrive/AI_techthon/original_data/elbow_plank/train/39.jfif')
image_cropped = image[0:280,0:1100]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped


'''
image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/elbow_plank/train/101.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

rectangle = (1,3,234,64)
#50, 30, 1218, 480
mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()


cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/train/71.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/train/71.jpg',mask_2)
# Out:
# True

# %%
rgb_cropped = image_rgb_nobg[130:475,15:940]

plt.imshow(rgb_cropped, cmap='gray')
                             
mask_cropped = mask_2[130:475,15:940]
plt.imshow(mask_cropped, cmap='gray')

# %%
'''image = cv2.imread('drive/MyDrive/AI_techthon/original_data/leg_raised_plank/train/94.jpg')
image_cropped = image[150:1280,100:1100]

plt.imshow(image_cropped, cmap='gray')
plt.show()

image_bgr = image_cropped
'''

#77번 안했다 희수야
image_bgr = cv2.imread('drive/MyDrive/AI_techthon/original_data/leg_raised_plank/train/77.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

plt.imshow(image_bgr, cmap='gray')
plt.show()

rectangle = (5,5,355,223)
#50, 30, 1218, 480
mask = np.zeros(image_rgb.shape[:2], np.uint8)

bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,
            fgdModel,
            5,
            cv2.GC_INIT_WITH_RECT)

mask_2 = np.where((mask==2) | (mask==0), 0, 1).astype('uint8')

image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]
plt.imshow(image_rgb_nobg)
plt.show()

plt.imshow(mask, cmap='gray'), plt.axis('off')
plt.show()

plt.imshow(mask_2, cmap='gray'), plt.axis('off')
plt.show()


cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/train/47.jpg',image_rgb_nobg)
cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/train/47.jpg',mask_2)
# Out:
# True

# %%
#cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/train/60.jpg',image_rgb_nobg)
#cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/train/60.jpg',mask_2)
# Out:
# True

# %%
#(32,92,759,263)

rgb_cropped = image_rgb_nobg[92:355,32:791]

plt.imshow(rgb_cropped, cmap='gray')
                             
mask_cropped = mask_2[92:355,32:791]
plt.imshow(mask_cropped, cmap='gray')

# %%
#cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/train/43.jpg',rgb_cropped)
#cv2.imwrite('./drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/train/43.jpg',mask_cropped)
# Out:
# True
