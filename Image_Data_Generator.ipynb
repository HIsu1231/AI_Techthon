# %% [markdown]
# <a href="https://colab.research.google.com/github/HIsu1231/AI_Techthon/blob/main/Image_Data_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
path = 'drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/test'

data_datagen = ImageDataGenerator(rescale=1./255)

data_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=15,
                                  shear_range=0.5,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')

filename_in_dir=[]

for (root, dirs, files) in os.walk(path):

    for fname in files:
        
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)

cnt=0

for file_image in filename_in_dir:
   
   print(file_image)

   img=load_img(file_image)
   x = img_to_array(img)
   x = x.reshape((1,) + x.shape)

   i = 0
   
   for batch in data_datagen.flow(x, save_to_dir = path, save_prefix='new', save_format='jpg'):
      i+=1

      cnt+=1

      print("batch:", i)
      if i>6:
        break
# Out:
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/test/1.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/test/3.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/test/4.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/test/5.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/test/6.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/test/7.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/test/8.jpg
# ...

# %%
print(cnt)
# Out:
# 210

# %%
path = 'drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/train'

data_datagen = ImageDataGenerator(rescale=1./255)

data_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=15,
                                  shear_range=0.5,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')

filename_in_dir=[]

for (root, dirs, files) in os.walk(path):

    for fname in files:
        
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)

cnt=0

for file_image in filename_in_dir:
   
   print(file_image)

   img=load_img(file_image)
   x = img_to_array(img)
   x = x.reshape((1,) + x.shape)

   i = 0
   
   for batch in data_datagen.flow(x, save_to_dir = path, save_prefix='new', save_format='jpg'):
      i+=1

      cnt+=1

      print("batch:", i)
      if i>6:
        break
# Out:
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/train/1.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/train/2.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/train/3.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/train/4.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/train/5.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/elbow_plank/train/6.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# ...

# %%
print(cnt)
# Out:
# 497

# %%
path = 'drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/test'

data_datagen = ImageDataGenerator(rescale=1./255)

data_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=15,
                                  shear_range=0.5,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')

filename_in_dir=[]

for (root, dirs, files) in os.walk(path):

    for fname in files:
        
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)

cnt=0

for file_image in filename_in_dir:
   
   print(file_image)

   img=load_img(file_image)
   x = img_to_array(img)
   x = x.reshape((1,) + x.shape)

   i = 0
   
   for batch in data_datagen.flow(x, save_to_dir = path, save_prefix='new', save_format='jpg'):
      i+=1

      cnt+=1

      print("batch:", i)
      if i>6:
        break
# Out:
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/test/1.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/test/3.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/test/4.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/test/5.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/test/6.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/test/7.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/test/8.jpg
# batch: 1
# ...

# %%
print(cnt)
# Out:
# 210

# %%
path = 'drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/train'

data_datagen = ImageDataGenerator(rescale=1./255)

data_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=15,
                                  shear_range=0.5,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')

filename_in_dir=[]

for (root, dirs, files) in os.walk(path):

    for fname in files:
        
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)

cnt=0

for file_image in filename_in_dir:
   
   print(file_image)

   img=load_img(file_image)
   x = img_to_array(img)
   x = x.reshape((1,) + x.shape)

   i = 0
   
   for batch in data_datagen.flow(x, save_to_dir = path, save_prefix='new', save_format='jpg'):
      i+=1

      cnt+=1

      print("batch:", i)
      if i>6:
        break
# Out:
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/train/1.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/train/2.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/train/3.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/train/4.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/train/5.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/train/6.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/elbow_plank/train/7.jpg
# batch: 1
# ...

# %%
print(cnt)
# Out:
# 497

# %%
path = 'drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/train'
data_datagen = ImageDataGenerator(rescale=1./255)

data_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=15,
                                  shear_range=0.5,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')

filename_in_dir=[]

for (root, dirs, files) in os.walk(path):

    for fname in files:
        
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)

cnt=0

for file_image in filename_in_dir:
   
   print(file_image)

   img=load_img(file_image)
   x = img_to_array(img)
   x = x.reshape((1,) + x.shape)

   i = 0
   
   for batch in data_datagen.flow(x, save_to_dir = path, save_prefix='new', save_format='jpg'):
      i+=1

      cnt+=1

      print("batch:", i)
      if i>6:
        break
# Out:
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/train/1.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/train/2.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/train/4.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/train/5.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/train/6.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/train/7.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# ...

# %%
print(cnt)
# Out:
# 490

# %%
path = 'drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/test'
data_datagen = ImageDataGenerator(rescale=1./255)

data_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=15,
                                  shear_range=0.5,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')

filename_in_dir=[]

for (root, dirs, files) in os.walk(path):

    for fname in files:
        
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)

cnt=0

for file_image in filename_in_dir:
   
   print(file_image)

   img=load_img(file_image)
   x = img_to_array(img)
   x = x.reshape((1,) + x.shape)

   i = 0
   
   for batch in data_datagen.flow(x, save_to_dir = path, save_prefix='new', save_format='jpg'):
      i+=1

      cnt+=1

      print("batch:", i)
      if i>6:
        break
# Out:
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/test/2.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/test/3.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/test/5.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/test/6.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/test/7.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/bin/leg_raised_plank/test/8.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# ...

# %%
print(cnt)
# Out:
# 210

# %%
path = 'drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/train'
data_datagen = ImageDataGenerator(rescale=1./255)

data_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=15,
                                  shear_range=0.5,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')

filename_in_dir=[]

for (root, dirs, files) in os.walk(path):

    for fname in files:
        
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)

cnt=0

for file_image in filename_in_dir:
   
   print(file_image)

   img=load_img(file_image)
   x = img_to_array(img)
   x = x.reshape((1,) + x.shape)

   i = 0
   
   for batch in data_datagen.flow(x, save_to_dir = path, save_prefix='new', save_format='jpg'):
      i+=1

      cnt+=1

      print("batch:", i)
      if i>6:
        break
# Out:
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/train/1.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/train/2.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/train/4.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/train/5.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/train/6.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/train/7.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# ...

# %%
print(cnt)
# Out:
# 490

# %%
path = 'drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/test'

data_datagen = ImageDataGenerator(rescale=1./255)

data_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=15,
                                  shear_range=0.5,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')

filename_in_dir=[]

for (root, dirs, files) in os.walk(path):

    for fname in files:
        
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)

cnt=0

for file_image in filename_in_dir:
   
   print(file_image)

   img=load_img(file_image)
   x = img_to_array(img)
   x = x.reshape((1,) + x.shape)

   i = 0
   
   for batch in data_datagen.flow(x, save_to_dir = path, save_prefix='new', save_format='jpg'):
      i+=1

      cnt+=1

      print("batch:", i)
      if i>6:
        break
# Out:
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/test/2.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/test/3.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/test/5.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/test/6.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/test/7.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# drive/MyDrive/AI_techthon/preprocessing_data/color/leg_raised_plank/test/8.jpg
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# ...

# %%
print(cnt)
# Out:
# 210

# %%
import os
import cv2
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from numpy import array
import tensorflow as tf
import random

path_folder_list = './drive/MyDrive/data'

# %%
train_folder_list = array(os.listdir(path_folder_list))

for i in range(len(train_folder_list)):

    path = os.path.join(path_folder_list, train_folder_list[i])
    train_path = path + '/train'

    img_list = os.listdir(train_path)

    print(len(img_list))
# Out:
# 619
# 584
# 584
# 586

# %%
train_folder_list = array(os.listdir(path_folder_list))

for i in range(len(train_folder_list)):

    path = os.path.join(path_folder_list, train_folder_list[i])
    train_path = path + '/test'

    img_list = os.listdir(train_path)

    print(len(img_list))
# Out:
# 238
# 235
# 237
# 223
